# %%
from County import County
from generate_plots import generate_plot

# %%
from update_database import update_database
update_database()

# %%
generate_plot(County('Montgomery','Ohio'), 'casesnew')
# Out:
# 'images/Montgomery_2020-11-23.png'

# %%
generate_plot(County('Greene','Ohio'), 'casesnew')
# Out:
# 'images/Greene_2020-11-23.png'

# %%
generate_plot(County('Putnam','Tennessee'), 'casesnew')
# Out:
# 'images/Putnam_2020-11-23.png'
